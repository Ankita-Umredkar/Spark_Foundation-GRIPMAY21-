# %% [markdown]
# ## GRADUATE RATIONAL INTERNSHIP PROGRAM (THE SPARK FOUNDATION)
# #### DATA SCIENCE AND BUSINESS ANALYTICS
#
# #### GRIPMAY21

# %% [markdown]
# #### Author: Ankita Umredkar

# %% [markdown]
# ##### Task 3: Exploring Data Analysis- Retail
# In this task we will perform 'Exploratory Data Analysis' on dataset 'Sample Superstore'. As a busness manager we will try to find out the weak areas where we can work to make more profit also. what all business problems can be derived by exploring the data.

# %% [markdown]
# ####  Import and reading thd dataset.

# %%
#import all the required libraries.
import pandas as pd
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\Admin\\Desktop\\Python\\Task 3(Exploratory Data Analysis - Retail)\\SampleSuperstore.csv')
print("Dataset imported successfully")
# Out:
# Dataset imported successfully

# %% [markdown]
# #### Displaying first 5 rows of dataset

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# #### Displaying last 5 rows of dataset

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# #### Getting the type of column/Attribute

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# #### To count total number of rows and column available in dataset

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# There is a 9994 rows and 13 column present in this dataset

# %% [markdown]
# #### To displaying Number of dataset columns

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# #### Describing the Dataset

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# #### To check whether Dataset values are null or not

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Here there is no null value is there in dataset

# %% [markdown]
# #### Summary of Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# #### To find is there any duplicate entries are present or not in dataset using duplicated() method.

# %%
data.duplicated().sum()
# Out:
# 17

# %% [markdown]
# There is a 17 duplicate entries are present in dataset.

# %% [markdown]
# #### Droppping the duplicate entries from dataset using drop_duplicates() method.

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# Here duplicate entries dropped from dataset

# %%
dataset.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# #### Calculating the Inter Quartile Range

# %%
Q1= data.quantile(0.25)
Q3= data.quantile(0.75)
IQR= Q3-Q1
print(IQR)
# Out:
# Postal Code    66785.00000
# Sales            192.66000
# Quantity           3.00000
# Discount           0.20000
# Profit            27.63525
# dtype: float64

# %% [markdown]
# #### Total Consumption in US in various Sectors

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(15,15))
sns.barplot(x='Sub-Category', y='Profit', data=data, palette='Spectral')
plt.suptitle('Consumption in United States', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Consumption in United States')

# %%
top_Sales = data.groupby("State").Sales.sum().nlargest(n=50)
top_Profit = data.groupby("State").Profit.sum().nlargest(n=50)

# %% [markdown]
# #### Total Sales in different states in US in Descending Order

# %%
top_Sales.index
# Out:
# Index(['California', 'New York', 'Texas', 'Washington', 'Pennsylvania',
#        'Florida', 'Illinois', 'Ohio', 'Michigan', 'Virginia', 'North Carolina',
#        'Indiana', 'Georgia', 'Kentucky', 'New Jersey', 'Arizona', 'Wisconsin',
#        'Colorado', 'Tennessee', 'Minnesota', 'Massachusetts', 'Delaware',
#        'Maryland', 'Rhode Island', 'Missouri', 'Oklahoma', 'Alabama', 'Oregon',
#        'Nevada', 'Connecticut', 'Arkansas', 'Utah', 'Mississippi', 'Louisiana',
#        'Vermont', 'South Carolina', 'Nebraska', 'New Hampshire', 'Montana',
#        'New Mexico', 'Iowa', 'Idaho', 'Kansas', 'District of Columbia',
#        'Wyoming', 'South Dakota', 'Maine', 'West Virginia', 'North Dakota'],
#       dtype='object', name='State')

# %% [markdown]
# #### Total Profit in different States in US in Descending Order

# %%
top_Profit.index
# Out:
# Index(['California', 'New York', 'Washington', 'Michigan', 'Virginia',
#        'Indiana', 'Georgia', 'Kentucky', 'Minnesota', 'Delaware', 'New Jersey',
#        'Wisconsin', 'Rhode Island', 'Maryland', 'Massachusetts', 'Missouri',
#        'Alabama', 'Oklahoma', 'Arkansas', 'Connecticut', 'Nevada',
#        'Mississippi', 'Utah', 'Vermont', 'Louisiana', 'Nebraska', 'Montana',
#        'South Carolina', 'New Hampshire', 'Iowa', 'New Mexico',
#        'District of Columbia', 'Kansas', 'Idaho', 'Maine', 'South Dakota',
#        'North Dakota', 'West Virginia', 'Wyoming', 'Oregon', 'Florida',
#        'Arizona', 'Tennessee', 'Colorado', 'North Carolina', 'Illinois',
#        'Pennsylvania', 'Ohio', 'Texas'],
#       dtype='object', name='State')

# %%
plt.style.use('seaborn')
top_Sales.plot(kind = 'bar', figsize=(20,10), fontsize =20)
plt.xlabel("States", fontsize=15)
plt.ylabel("Total Sales", fontsize=15)
plt.title("Top 10 States by Sales", fontsize=20)
plt.show()

# %%
plt.style.use('seaborn')
top_Profit.plot(kind = 'bar', figsize=(20,10), fontsize =20)
plt.xlabel("States", fontsize=15)
plt.ylabel("Total Profit", fontsize=15)
plt.title("Top 10 States by Profit", fontsize=20)
plt.show()

# %%
figsize=(10,10)
sns.pairplot(data,hue='Sub-Category')

# %% [markdown]
# #### Hit Map for different Categories

# %%
f,ax= plt.subplots(figsize=(12,8))
sns.heatmap(data.corr(), annot=True , cmap='inferno', lw=8, linecolor='white')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Category VS Profit

# %%
plt.figure(figsize=[12,8])
ax = sns.barplot(x="Category", y='Profit', data=data, palette='Set2')

# %% [markdown]
# #### Category VS Profit in Different Regions in US

# %%
plt.figure(figsize=[12,8])
ax = sns.barplot(x='Region', y='Profit', hue='Category', data=data, palette='Set2')

# %% [markdown]
# #### Sub-Category VS Profit

# %%
plt.figure(figsize=[10,8])
ax=sns.barplot(x='Sub-Category',y='Profit', data=data, palette='magma')
plt.xlabel("Subcategory", fontsize=15)
plt.ylabel("Profit", fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Sub-Category VS Sales

# %%
plt.figure(figsize=[15,12])
ax=sns.barplot(x='Sub-Category',y='Sales', data=data, palette='magma')
plt.xlabel("Subcategories", fontsize=20)
plt.ylabel("Sales", fontsize=20)
plt.show()

# %%
plt.figure(figsize=[15,12])
ax = sns.barplot(x="Sub-Category", y="Profit", data=data, palette="viridis")
plt.xlabel("SubCategories", fontsize=20)
plt.ylabel("Profit",fontsize=20)
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# # Task 3 Completed

# %% [markdown]
# # Thank You
